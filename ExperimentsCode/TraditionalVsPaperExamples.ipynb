# %%
import nltk.corpus
from sematch.semantic.similarity import WordNetSimilarity
from nltk.tokenize.treebank import TreebankWordDetokenizer
from nltk.corpus import wordnet as wn

# %%
sentences = [list(map(lambda x:x.lower(), sentence)) for sentence in nltk.corpus.brown.sents()]

# %%
# Example sentence.
sentences[150]
# Out:
# ['opponents',
#  'generally',
#  'argued',
#  'that',
#  'the',
#  'ballot',
#  "couldn't",
#  'give',
#  'enough',
#  'information',
#  'about',
#  'tax',
#  'proposals',
#  'for',
#  'the',
#  'voters',
#  'to',
#  'make',
#  'an',
#  'intelligent',
#  'choice',
#  '.']

# %%
# Lowercases all words currently for simplicity.
def watermark_sentence(orig_sentence):
    # Can add
    sentence = [word.lower() for word in orig_sentence.copy()]
    
    # Get the best synonym starting with the word at the end of the sentence.
    result = get_best_synonym(sentence)
    
    if result is None:
        return None
    
    best_synonym, best_synonym_index = result
    
    # Replace the target word with the synonym.
    sentence[best_synonym_index] = best_synonym
    
    return sentence

# %%
def get_all_synonyms(word):
    word = word.lower()
    synonyms = []
    scores = []
    for ss in wn.synsets(word):
        synonyms.extend([lemma.lower() for lemma in ss.lemma_names()])
        for sim in ss.similar_tos():
            synonyms_batch = sim.lemma_names()
            synonyms.extend(synonyms_batch)
    synonyms = set(synonyms)
    if word in synonyms:
        synonyms.remove(word)
    synonyms = [synonym.replace('_',' ') for synonym in synonyms]
    return synonyms

# %%
# Gets the index and synonym that is the highest scored synonym.
def get_best_synonym(sentence):
    
    score_list = []
    word_list = []
    
    for i in range(len(sentence)):
        word = sentence[i]
        all_synonyms = get_all_synonyms(word)
        
        # Ignore current word if there are no synonyms.
        if len(all_synonyms) == 0: 
            # append 0 score.
            score_list.append(0)
            word_list.append("none")
            continue
        
        wns = WordNetSimilarity()
        similarity_scores = [wns.word_similarity(word, syn) for syn in all_synonyms]

        # Uncomment the following to see process.
        #print(word)
        #print(all_synonyms)
        
        max_score = max(similarity_scores)
        best_synonym_for_current_idx = all_synonyms[similarity_scores.index(max_score)]
        
        word_list.append(best_synonym_for_current_idx)
        score_list.append(max_score)
        
    best_score_overall = max(score_list)
    
    if best_score_overall == 0:
        print("No available synonyms")
        return None
    
    best_word_idx = score_list.index(best_score_overall)
    best_word = word_list[best_word_idx]
    
    return best_word, best_word_idx

# %% [markdown]
# # Traditional Examples

# %%
start_num_hundreds = 0
num_hundreds = 1
for i in range(start_num_hundreds + 1, num_hundreds + start_num_hundreds + 1):
    start_range = (i - 1) * 100
    end_range = (i) * 100
    
    print(start_range, end_range)
    
    current_sentences = sentences[start_range:end_range]

    watermarked_sents = []
    unmarked_sents = []
    
    for i in range(len(current_sentences)):
        sentence = current_sentences[i].copy()
        
        if len(sentence) < 5:
            continue
        
        result = watermark_sentence(sentence)
        
        if result is not None:
            watermarked_sents.append(result)
            unmarked_sents.append([word.lower() for word in current_sentences[i]])
# Out:
# 0 100

# %%
detokenizer = TreebankWordDetokenizer()

# %%
print(detokenizer.detokenize(watermarked_sents[0]))
# Out:
# the fulton county thousand jury said friday an investigation of atlanta's recent primary election produced "no evidence" that any irregularities took place.

# %%
print(detokenizer.detokenize(watermarked_sents[2]))
# Out:
# the september-october condition jury had been charged by fulton superior court judge durwood pye to investigate reports of possible "irregularities" in the hard-fought primary which was won by mayor-nominate ivan allen jr. .

# %% [markdown]
# # DeepTextMarkoriginal

# %%
import sys

# %%
# Add previous folder to thDeepTextMarker variable temporarily so the python modules can be accessed.
sys.path.append('../')

# %%
from DeepTextMarker import DeepTextMarker

# %%
marker = DeepTextMarker()

# %%
print(detokenizer.detokenize(sentences[0]))
# Out:
# the fulton county grand jury said friday an investigation of atlanta's recent primary election produced "no evidence" that any irregularities took place.

# %%
print(detokenizer.detokenize(marker.watermark_single_sentence(sentences[0])))
# Out:
# the fulton county grand jury said friday an investigation of atlanta's recent primary elections produced "no evidence" that any irregularities took place.

# %%
print(detokenizer.detokenize(sentences[2]))
# Out:
# the september-october term jury had been charged by fulton superior court judge durwood pye to investigate reports of possible "irregularities" in the hard-fought primary which was won by mayor-nominate ivan allen jr. .

# %%
print(detokenizer.detokenize(marker.watermark_single_sentence(sentences[2])))
# Out:
# the september-october term jury had been charged by fulton superior courts judge durwood pye to investigate reports of possible "irregularities" in the hard-fought primary which was won by mayor-nominate ivan allen jr. .

# %% [markdown]
# # Both

# %%
trimmed_sents = [sent for sent in sentences[0:100] if len(sent) >= 5]

# %%
for i in range(0, 100):
    original = trimmed_sents[i]
    
    traditional = watermarked_sents[i]
    deepTextMark = marker.watermark_single_sentence(original)
    
    # Printed in latex format.
    print("\\begin{enumerate}")
    print("\\item " + detokenizer.detokenize(original).capitalize())
    print("\\item " + detokenizer.detokenize(traditional).capitalize())
    print("\\item " + detokenizer.detokenize(deepTextMark).capitalize())
    print("\\end{enumerate}")
    print()
# Out:
# \begin{enumerate}
# \item The fulton county grand jury said friday an investigation of atlanta's recent primary election produced "no evidence" that any irregularities took place.
# \item The fulton county thousand jury said friday an investigation of atlanta's recent primary election produced "no evidence" that any irregularities took place.
# \item The fulton county grand jury said friday an investigation of atlanta's recent primary elections produced "no evidence" that any irregularities took place.
# \end{enumerate}
#
# \begin{enumerate}
# \item The jury further said in term-end presentments that the city executive committee, which had over-all charge of the election, "deserves the praise and thanks of the city of atlanta" for the manner in which the election was conducted.
# \item The panel further said in term-end presentments that the city executive committee, which had over-all charge of the election, "deserves the praise and thanks of the city of atlanta" for the manner in which the election was conducted.
# \item The jury further said in term-end presentments that the city executive committee, which had over-all charge of the election, "deserves the praise and thanks of the city of atl" for the manner in which the election was conducted.
# \end{enumerate}
#
# \begin{enumerate}
# \item The september-october term jury had been charged by fulton superior court judge durwood pye to investigate reports of possible "irregularities" in the hard-fought primary which was won by mayor-nominate ivan allen jr. .
# \item The september-october condition jury had been charged by fulton superior court judge durwood pye to investigate reports of possible "irregularities" in the hard-fought primary which was won by mayor-nominate ivan allen jr. .
# \item The september-october term jury had been charged by fulton superior courts judge durwood pye to investigate reports of possible "irregularities" in the hard-fought primary which was won by mayor-nominate ivan allen jr. .
# \end{enumerate}
#
# \begin{enumerate}
# \item "only a relative handful of such reports was received", the jury said, "considering the widespread interest in the election, the number of voters and the size of this city".
# \item "only adenine relative handful of such reports was received", the jury said, "considering the widespread interest in the election, the number of voters and the size of this city".
# \item "only a relative handful of such reports was received", the jury said, "considering the widespread interest in the elections, the number of voters and the size of this city".
# \end{enumerate}
#
# \begin{enumerate}
# \item The jury said it did find that many of georgia's registration and election laws "are outmoded or inadequate and often ambiguous".
# \item The panel said it did find that many of georgia's registration and election laws "are outmoded or inadequate and often ambiguous".
# \item The jury said it did find that many of georgia's register and election laws "are outmoded or inadequate and often ambiguous".
# \end{enumerate}
#
# \begin{enumerate}
# \item It recommended that fulton legislators act "to have these laws studied and revised to the end of modernizing and improving them".
# \item It recommended that fulton legislator act "to have these laws studied and revised to the end of modernizing and improving them".
# \item It recommended that fulton legislators act "to have these laws studied and revised to the end of modernizing and improve them".
# \end{enumerate}
#
# \begin{enumerate}
# \item The grand jury commented on a number of other topics, among them the atlanta and fulton county purchasing departments which it said "are well operated and follow generally accepted practices which inure to the best interest of both governments".
# \item The thousand jury commented on a number of other topics, among them the atlanta and fulton county purchasing departments which it said "are well operated and follow generally accepted practices which inure to the best interest of both governments".
# \item The grand jury commented on a number of other topics, among them the atl and fulton county purchasing departments which it said "are well operated and follow generally accepted practices which inure to the best interest of both governments".
# \end{enumerate}
#
# \begin{enumerate}
# \item However, the jury said it believes "these two offices should be combined to achieve greater efficiency and reduce the cost of administration".
# \item However, the panel said it believes "these two offices should be combined to achieve greater efficiency and reduce the cost of administration".
# \item However, the jury said it believes "these two offices should be combined to achieve greater efficiency and reduce the costs of administration".
# \end{enumerate}
#
# \begin{enumerate}
# \item The city purchasing department, the jury said, "is lacking in experienced clerical personnel as a result of city personnel policies".
# \item The metropolis purchasing department, the jury said, "is lacking in experienced clerical personnel as a result of city personnel policies".
# \item The city purchasing department, the jury said, "is lacking in experienced clerical staff as a result of city personnel policies".
# \end{enumerate}
#
# \begin{enumerate}
# \item It urged that the city "take steps to remedy" this problem.
# \item It urged that the metropolis "take steps to remedy" this problem.
# \item It urged that the city "take steps to remedy" this problems.
# \end{enumerate}
#
# \begin{enumerate}
# \item Implementation of georgia's automobile title law was also recommended by the outgoing jury.
# \item Effectuation of georgia's automobile title law was also recommended by the outgoing jury.
# \item Implementation of georgia's automobile titles law was also recommended by the outgoing jury.
# \end{enumerate}
#
# \begin{enumerate}
# \item It urged that the next legislature "provide enabling funds and re-set the effective date so that an orderly implementation of the law may be effected".
# \item It urged that the next law-makers "provide enabling funds and re-set the effective date so that an orderly implementation of the law may be effected".
# \item It urged that the next legislature "providing enabling funds and re-set the effective date so that an orderly implementation of the law may be effected".
# \end{enumerate}
#
# \begin{enumerate}
# \item The grand jury took a swipe at the state welfare department's handling of federal funds granted for child welfare services in foster homes.
# \item The thousand jury took a swipe at the state welfare department's handling of federal funds granted for child welfare services in foster homes.
# \item The grand jury took a swipe at the state welfare department's handling of federal fund granted for child welfare services in foster homes.
# \end{enumerate}
#
# \begin{enumerate}
# \item "this is one of the major items in the fulton county general assistance program", the jury said, but the state welfare department "has seen fit to distribute these funds through the welfare departments of all the counties in the state with the exception of fulton county, which receives none of this money.
# \item "this is ace of the major items in the fulton county general assistance program", the jury said, but the state welfare department "has seen fit to distribute these funds through the welfare departments of all the counties in the state with the exception of fulton county, which receives none of this money.
# \item "this is one of the major items in the fulton county general assistance program", the jury said, but the state welfare department "has seen fit to distribute these fund through the welfare departments of all the counties in the state with the exception of fulton county, which receives none of this money.
# \end{enumerate}
#
# \begin{enumerate}
# \item The jurors said they realize "a proportionate distribution of these funds might disable this program in our less populous counties".
# \item The juryman said they realize "a proportionate distribution of these funds might disable this program in our less populous counties".
# \item The jurors said they realize "a proportionate distribution of these fund might disable this program in our less populous counties".
# \end{enumerate}
#
# \begin{enumerate}
# \item Nevertheless, "we feel that in the future fulton county should receive some portion of these available funds", the jurors said.
# \item Nevertheless, "we flavor that in the future fulton county should receive some portion of these available funds", the jurors said.
# \item Nevertheless, "we feel that in the future fulton county should receive some portion of these available fund", the jurors said.
# \end{enumerate}
#
# \begin{enumerate}
# \item "failure to do this will continue to place a disproportionate burden" on fulton taxpayers.
# \item "loser to do this will continue to place a disproportionate burden" on fulton taxpayers.
# \item "failure to do this will continues to place a disproportionate burden" on fulton taxpayers.
# \end{enumerate}
#
# \begin{enumerate}
# \item The jury also commented on the fulton ordinary's court which has been under fire for its practices in the appointment of appraisers, guardians and administrators and the awarding of fees and compensation.
# \item The panel also commented on the fulton ordinary's court which has been under fire for its practices in the appointment of appraisers, guardians and administrators and the awarding of fees and compensation.
# \item The jury also commented on the fulton ordinary's courts which has been under fire for its practices in the appointment of appraisers, guardians and administrators and the awarding of fees and compensation.
# \end{enumerate}
#
# \begin{enumerate}
# \item The jury said it found the court "has incorporated into its operating procedures the recommendations" of two previous grand juries, the atlanta bar association and an interim citizens committee.
# \item The panel said it found the court "has incorporated into its operating procedures the recommendations" of two previous grand juries, the atlanta bar association and an interim citizens committee.
# \item The jury said it found the courts "has incorporated into its operating procedures the recommendations" of two previous grand juries, the atlanta bar association and an interim citizens committee.
# \end{enumerate}
#
# \begin{enumerate}
# \item "these actions should serve to protect in fact and in effect the court's wards from undue costs and its appointed and elected servants from unmeritorious criticisms", the jury said.
# \item "these activeness should serve to protect in fact and in effect the court's wards from undue costs and its appointed and elected servants from unmeritorious criticisms", the jury said.
# \item "these actions should serve to protecting in fact and in effect the court's wards from undue costs and its appointed and elected servants from unmeritorious criticisms", the jury said.
# \end{enumerate}
#
# \begin{enumerate}
# \item Regarding atlanta's new multi-million-dollar airport, the jury recommended "that when the new management takes charge jan. 1 the airport be operated in a manner that will eliminate political influences".
# \item Regarding atlanta's new multi-million-dollar airdrome, the jury recommended "that when the new management takes charge jan. 1 the airport be operated in a manner that will eliminate political influences".
# \item Regarding atlanta's new multi-million-dollar airport, the jury recommended "that when the new management takes charge jan. 1 the airport be operated in a manner that will eliminate politics influences".
# \end{enumerate}
#
# \begin{enumerate}
# \item The jury did not elaborate, but it added that "there should be periodic surveillance of the pricing practices of the concessionaires for the purpose of keeping the prices reasonable".
# \item The panel did not elaborate, but it added that "there should be periodic surveillance of the pricing practices of the concessionaires for the purpose of keeping the prices reasonable".
# \item The jury did not elaborate, but it added that "there should be periodic surveillance of the pricing practices of the concessionaires for the purpose of keeping the price reasonable".
# \end{enumerate}
#
# \begin{enumerate}
# \item On other matters, the jury recommended that: (1)
# \item On other affair, the jury recommended that: (1)
# \item On other matter, the jury recommended that: (1)
# \end{enumerate}
#
# \begin{enumerate}
# \item Four additional deputies be employed at the fulton county jail and "a doctor, medical intern or extern be employed for night and weekend duty at the jail".
# \item Quatern additional deputies be employed at the fulton county jail and "a doctor, medical intern or extern be employed for night and weekend duty at the jail".
# \item Four additional deputies be employed at the fulton county prison and "a doctor, medical intern or extern be employed for night and weekend duty at the jail".
# \end{enumerate}
#
# \begin{enumerate}
# \item Fulton legislators "work with city officials to pass enabling legislation that will permit the establishment of a fair and equitable" pension plan for city employes.
# \item Fulton legislator "work with city officials to pass enabling legislation that will permit the establishment of a fair and equitable" pension plan for city employes.
# \item Fulton legislators "work with city officials to pass enabling legislation that will permit the establishment of a fair and equitable" pensions plan for city employes.
# \end{enumerate}
#
# \begin{enumerate}
# \item The jury praised the administration and operation of the atlanta police department, the fulton tax commissioner's office, the bellwood and alpharetta prison farms, grady hospital and the fulton health department.
# \item The panel praised the administration and operation of the atlanta police department, the fulton tax commissioner's office, the bellwood and alpharetta prison farms, grady hospital and the fulton health department.
# \item The jury praised the administration and operation of the atl police department, the fulton tax commissioner's office, the bellwood and alpharetta prison farms, grady hospital and the fulton health department.
# \end{enumerate}
#
# \begin{enumerate}
# \item Mayor william b. hartsfield filed suit for divorce from his wife, pearl williams hartsfield, in fulton superior court friday.
# \item Mayor william b. hartsfield filed case for divorce from his wife, pearl williams hartsfield, in fulton superior court friday.
# \item Mayor william b. hartsfield filed suit for divorce from his wife, pearl williams hartsfield, in fulton superior courts friday.
# \end{enumerate}
#
# \begin{enumerate}
# \item His petition charged mental cruelty.
# \item His prayer charged mental cruelty.
# \item His petitions charged mental cruelty.
# \end{enumerate}
#
# \begin{enumerate}
# \item The couple was married aug. 2, 1913.
# \item The duo was married aug. 2, 1913.
# \item The couple was marry aug. 2, 1913.
# \end{enumerate}
#
# \begin{enumerate}
# \item They have a son, william berry jr., and a daughter, mrs. j. m. cheshire of griffin.
# \item They have adenine son, william berry jr., and a daughter, mrs. j. m. cheshire of griffin.
# \item They have a son, william berry jr., and a wife, mrs. j. m. cheshire of griffin.
# \end{enumerate}
#
# \begin{enumerate}
# \item Attorneys for the mayor said that an amicable property settlement has been agreed upon.
# \item Lawyer for the mayor said that an amicable property settlement has been agreed upon.
# \item Lawyers for the mayor said that an amicable property settlement has been agreed upon.
# \end{enumerate}
#
# \begin{enumerate}
# \item The petition listed the mayor's occupation as "attorney" and his age as 71.
# \item The prayer listed the mayor's occupation as "attorney" and his age as 71.
# \item The petitions listed the mayor's occupation as "attorney" and his age as 71.
# \end{enumerate}
#
# \begin{enumerate}
# \item It listed his wife's age as 74 and place of birth as opelika, ala. .
# \item It listed his wife's geezerhood as 74 and place of birth as opelika, ala. .
# \item It listed his wife's age as 74 and places of birth as opelika, ala. .
# \end{enumerate}
#
# \begin{enumerate}
# \item The petition said that the couple has not lived together as man and wife for more than a year.
# \item The prayer said that the couple has not lived together as man and wife for more than a year.
# \item The petitions said that the couple has not lived together as man and wife for more than a year.
# \end{enumerate}
#
# \begin{enumerate}
# \item The hartsfield home is at 637 e. pelham rd. aj.
# \item The hartsfield abode is at 637 e. pelham rd. aj.
# \item The hartsfield house is at 637 e. pelham rd. aj.
# \end{enumerate}
#
# \begin{enumerate}
# \item Henry l. bowden was listed on the petition as the mayor's attorney.
# \item H l. bowden was listed on the petition as the mayor's attorney.
# \item Henry l. bowden was listed on the petitions as the mayor's attorney.
# \end{enumerate}
#
# \begin{enumerate}
# \item Hartsfield has been mayor of atlanta, with exception of one brief interlude, since 1937.
# \item Hartsfield ha been mayor of atlanta, with exception of one brief interlude, since 1937.
# \item Hartsfield has been mayor of atl, with exception of one brief interlude, since 1937.
# \end{enumerate}
#
# \begin{enumerate}
# \item His political career goes back to his election to city council in 1923.
# \item His political calling goes back to his election to city council in 1923.
# \item His politics career goes back to his election to city council in 1923.
# \end{enumerate}
#
# \begin{enumerate}
# \item The mayor's present term of office expires jan. 1.
# \item The mayor's nowadays term of office expires jan. 1.
# \item The mayor's present term of office expiring jan. 1.
# \end{enumerate}
#
# \begin{enumerate}
# \item He will be succeeded by ivan allen jr., who became a candidate in the sept. 13 primary after mayor hartsfield announced that he would not run for reelection.
# \item Helium will be succeeded by ivan allen jr., who became a candidate in the sept. 13 primary after mayor hartsfield announced that he would not run for reelection.
# \item He will be succeeded by ivan allen jr., who became a candidates in the sept. 13 primary after mayor hartsfield announced that he would not run for reelection.
# \end{enumerate}
#
# \begin{enumerate}
# \item Georgia republicans are getting strong encouragement to enter a candidate in the 1962 governor's race, a top official said wednesday.
# \item Sakartvelo republicans are getting strong encouragement to enter a candidate in the 1962 governor's race, a top official said wednesday.
# \item Georgia republicans are getting strong encouragement to enter a candidate in the 1962 governor's race, a top official said tuesday.
# \end{enumerate}
#
# \begin{enumerate}
# \item Robert snodgrass, state gop chairman, said a meeting held tuesday night in blue ridge brought enthusiastic responses from the audience.
# \item Robert snodgrass, province gop chairman, said a meeting held tuesday night in blue ridge brought enthusiastic responses from the audience.
# \item Robert snodgrass, state gop chairman, said a meeting held thursday night in blue ridge brought enthusiastic responses from the audience.
# \end{enumerate}
#
# \begin{enumerate}
# \item State party chairman james w. dorsey added that enthusiasm was picking up for a state rally to be held sept. 8 in savannah at which newly elected texas sen. john tower will be the featured speaker.
# \item Province party chairman james w. dorsey added that enthusiasm was picking up for a state rally to be held sept. 8 in savannah at which newly elected texas sen. john tower will be the featured speaker.
# \item State party chairman james w. dorsey added that enthusiasm was picking up for a state rally to be held sept. 8 in savannah at which newly elected texas sen. john tower will be the featured speakers.
# \end{enumerate}
#
# \begin{enumerate}
# \item In the blue ridge meeting, the audience was warned that entering a candidate for governor would force it to take petitions out into voting precincts to obtain the signatures of registered voters.
# \item Indiana the blue ridge meeting, the audience was warned that entering a candidate for governor would force it to take petitions out into voting precincts to obtain the signatures of registered voters.
# \item In the blue ridge meeting, the audience was warned that entering a candidate for governor would force it to take petition out into voting precincts to obtain the signatures of registered voters.
# \end{enumerate}
#
# \begin{enumerate}
# \item Despite the warning, there was a unanimous vote to enter a candidate, according to republicans who attended.
# \item Contempt the warning, there was a unanimous vote to enter a candidate, according to republicans who attended.
# \item Despite the warning, there was a unanimous vote to enter a candidate, according to democrats who attended.
# \end{enumerate}
#
# \begin{enumerate}
# \item When the crowd was asked whether it wanted to wait one more term to make the race, it voted no--and there were no dissents.
# \item When the bunch was asked whether it wanted to wait one more term to make the race, it voted no--and there were no dissents.
# \item When the crowd was asked whether it wanted to wait one more term to make the races, it voted no--and there were no dissents.
# \end{enumerate}
#
# \begin{enumerate}
# \item The largest hurdle the republicans would have to face is a state law which says that before making a first race, one of two alternative courses must be taken: 1
# \item The largest vault the republicans would have to face is a state law which says that before making a first race, one of two alternative courses must be taken: 1
# \item The largest hurdle the republicans would have to face is a state law which says that before making a first races, one of two alternative courses must be taken: 1
# \end{enumerate}
#
# \begin{enumerate}
# \item Five per cent of the voters in each county must sign petitions requesting that the republicans be allowed to place names of candidates on the general election ballot, or 2
# \item Quintuplet per cent of the voters in each county must sign petitions requesting that the republicans be allowed to place names of candidates on the general election ballot, or 2
# \item Five per cent of the voters in each county must sign petition requesting that the republicans be allowed to place names of candidates on the general election ballot, or 2
# \end{enumerate}
#
# \begin{enumerate}
# \item The republicans must hold a primary under the county unit system--a system which the party opposes in its platform.
# \item The republican must hold a primary under the county unit system--a system which the party opposes in its platform.
# \item The democrats must hold a primary under the county unit system--a system which the party opposes in its platform.
# \end{enumerate}
#
# \begin{enumerate}
# \item Sam caldwell, state highway department public relations director, resigned tuesday to work for lt. gov. garland byrd's campaign.
# \item Sam caldwell, province highway department public relations director, resigned tuesday to work for lt. gov. garland byrd's campaign.
# \item Sam caldwell, state highway department public relations director, resigned tuesday to work for lt. gov. garland byrd's campaigns.
# \end{enumerate}
#
# \begin{enumerate}
# \item Caldwell's resignation had been expected for some time.
# \item Caldwell's surrender had been expected for some time.
# \item Caldwell's resigned had been expected for some time.
# \end{enumerate}
#
# \begin{enumerate}
# \item He will be succeeded by rob ledford of gainesville, who has been an assistant more than three years.
# \item Helium will be succeeded by rob ledford of gainesville, who has been an assistant more than three years.
# \item He will be succeeded by rob ledford of gainesville, who has been an assistant more than three months.
# \end{enumerate}
#
# \begin{enumerate}
# \item When the gubernatorial campaign starts, caldwell is expected to become a campaign coordinator for byrd.
# \item When the gubernatorial effort starts, caldwell is expected to become a campaign coordinator for byrd.
# \item When the gubernatorial campaigns starts, caldwell is expected to become a campaign coordinator for byrd.
# \end{enumerate}
#
# \begin{enumerate}
# \item The georgia legislature will wind up its 1961 session monday and head for home--where some of the highway bond money it approved will follow shortly.
# \item The sakartvelo legislature will wind up its 1961 session monday and head for home--where some of the highway bond money it approved will follow shortly.
# \item The georgia legislature will wind up its 1961 session tuesday and head for home--where some of the highway bond money it approved will follow shortly.
# \end{enumerate}
#
# \begin{enumerate}
# \item Before adjournment monday afternoon, the senate is expected to approve a study of the number of legislators allotted to rural and urban areas to determine what adjustments should be made.
# \item Before dissolution monday afternoon, the senate is expected to approve a study of the number of legislators allotted to rural and urban areas to determine what adjustments should be made.
# \item Before adjournment tuesday afternoon, the senate is expected to approve a study of the number of legislators allotted to rural and urban areas to determine what adjustments should be made.
# \end{enumerate}
#
# \begin{enumerate}
# \item Gov. vandiver is expected to make the traditional visit to both chambers as they work toward adjournment.
# \item Gov. vandiver is expected to shuffle the traditional visit to both chambers as they work toward adjournment.
# \item Gov. vandiver is expected to make the traditional visit to both chambers as they working toward adjournment.
# \end{enumerate}
#
# \begin{enumerate}
# \item Vandiver likely will mention the $100 million highway bond issue approved earlier in the session as his first priority item.
# \item Vandiver likely testament mention the $100 million highway bond issue approved earlier in the session as his first priority item.
# \item Vandiver probably will mention the $100 million highway bond issue approved earlier in the session as his first priority item.
# \end{enumerate}
#
# \begin{enumerate}
# \item Meanwhile, it was learned the state highway department is very near being ready to issue the first $30 million worth of highway reconstruction bonds.
# \item Interim, it was learned the state highway department is very near being ready to issue the first $30 million worth of highway reconstruction bonds.
# \item Meanwhile, it was learned the state highway dept is very near being ready to issue the first $30 million worth of highway reconstruction bonds.
# \end{enumerate}
#
# \begin{enumerate}
# \item The bond issue will go to the state courts for a friendly test suit to test the validity of the act, and then the sales will begin and contracts let for repair work on some of georgia's most heavily traveled highways.
# \item The bail issue will go to the state courts for a friendly test suit to test the validity of the act, and then the sales will begin and contracts let for repair work on some of georgia's most heavily traveled highways.
# \item The bond issue will go to the state court for a friendly test suit to test the validity of the act, and then the sales will begin and contracts let for repair work on some of georgia's most heavily traveled highways.
# \end{enumerate}
#
# \begin{enumerate}
# \item A highway department source said there also is a plan there to issue some $3 million to $4 million worth of rural roads authority bonds for rural road construction work.
# \item Adenine highway department source said there also is a plan there to issue some $3 million to $4 million worth of rural roads authority bonds for rural road construction work.
# \item A highway department source said there also is a plan there to issue some $3 million to $4 million worth of rural roads authority bonds for rural road construction working.
# \end{enumerate}
#
# \begin{enumerate}
# \item The department apparently intends to make the rural roads authority a revolving fund under which new bonds would be issued every time a portion of the old ones are paid off by tax authorities.
# \item The section apparently intends to make the rural roads authority a revolving fund under which new bonds would be issued every time a portion of the old ones are paid off by tax authorities.
# \item The department apparently intends to make the rural roads authority a revolving funds under which new bonds would be issued every time a portion of the old ones are paid off by tax authorities.
# \end{enumerate}
#
# \begin{enumerate}
# \item Vandiver opened his race for governor in 1958 with a battle in the legislature against the issuance of $50 million worth of additional rural roads bonds proposed by then gov. marvin griffin.
# \item Vandiver opened his slipstream for governor in 1958 with a battle in the legislature against the issuance of $50 million worth of additional rural roads bonds proposed by then gov. marvin griffin.
# \item Vandiver opened his races for governor in 1958 with a battle in the legislature against the issuance of $50 million worth of additional rural roads bonds proposed by then gov. marvin griffin.
# \end{enumerate}
#
# \begin{enumerate}
# \item The highway department source told the constitution, however, that vandiver has not been consulted yet about the plans to issue the new rural roads bonds.
# \item The highway section source told the constitution, however, that vandiver has not been consulted yet about the plans to issue the new rural roads bonds.
# \item The highway dept source told the constitution, however, that vandiver has not been consulted yet about the plans to issue the new rural roads bonds.
# \end{enumerate}
#
# \begin{enumerate}
# \item Schley county rep. b. d. pelham will offer a resolution monday in the house to rescind the body's action of friday in voting itself a $10 per day increase in expense allowances.
# \item Schley county rep. b. d. pelham testament offer a resolution monday in the house to rescind the body's action of friday in voting itself a $10 per day increase in expense allowances.
# \item Schley county rep. b. d. pelham will offer a resolution monday in the house to rescind the body's action of friday in voting itself a $10 per day increase in expenses allowances.
# \end{enumerate}
#
# \begin{enumerate}
# \item Pelham said sunday night there was research being done on whether the "quickie" vote on the increase can be repealed outright or whether notice would have to first be given that reconsideration of the action would be sought.
# \item Pelham said sun night there was research being done on whether the "quickie" vote on the increase can be repealed outright or whether notice would have to first be given that reconsideration of the action would be sought.
# \item Pelham said saturday night there was research being done on whether the "quickie" vote on the increase can be repealed outright or whether notice would have to first be given that reconsideration of the action would be sought.
# \end{enumerate}
#
# \begin{enumerate}
# \item While emphasizing that technical details were not fully worked out, pelham said his resolution would seek to set aside the privilege resolution which the house voted through 87-31.
# \item Piece emphasizing that technical details were not fully worked out, pelham said his resolution would seek to set aside the privilege resolution which the house voted through 87-31.
# \item While emphasizing that technical details were not completely worked out, pelham said his resolution would seek to set aside the privilege resolution which the house voted through 87-31.
# \end{enumerate}
#
# \begin{enumerate}
# \item A similar resolution passed in the senate by a vote of 29-5.
# \item Adenine similar resolution passed in the senate by a vote of 29-5.
# \item A similar resolutions passed in the senate by a vote of 29-5.
# \end{enumerate}
#
# \begin{enumerate}
# \item As of sunday night, there was no word of a resolution being offered there to rescind the action.
# \item Axerophthol of sunday night, there was no word of a resolution being offered there to rescind the action.
# \item As of saturday night, there was no word of a resolution being offered there to rescind the action.
# \end{enumerate}
#
# \begin{enumerate}
# \item Pelham pointed out that georgia voters last november rejected a constitutional amendment to allow legislators to vote on pay raises for future legislature sessions.
# \item Pelham pointed out that sakartvelo voters last november rejected a constitutional amendment to allow legislators to vote on pay raises for future legislature sessions.
# \item Pelham pointed out that georgia voters last november rejected a constitutional amendments to allow legislators to vote on pay raises for future legislature sessions.
# \end{enumerate}
#
# \begin{enumerate}
# \item A veteran jackson county legislator will ask the georgia house monday to back federal aid to education, something it has consistently opposed in the past.
# \item Adenine veteran jackson county legislator will ask the georgia house monday to back federal aid to education, something it has consistently opposed in the past.
# \item A veteran jackson county legislator will ask the georgia house tuesday to back federal aid to education, something it has consistently opposed in the past.
# \end{enumerate}
#
# \begin{enumerate}
# \item Rep. mac barber of commerce is asking the house in a privilege resolution to "endorse increased federal support for public education, provided that such funds be received and expended" as state funds.
# \item Rep. mack barber of commerce is asking the house in a privilege resolution to "endorse increased federal support for public education, provided that such funds be received and expended" as state funds.
# \item Rep. mac barber of commerce is asking the house in a privilege resolution to "endorse increased federal supporting for public education, provided that such funds be received and expended" as state funds.
# \end{enumerate}
#
# \begin{enumerate}
# \item Barber, who is in his 13th year as a legislator, said there "are some members of our congressional delegation in washington who would like to see it (the resolution) passed".
# \item Barber, who is indiana his 13th year as a legislator, said there "are some members of our congressional delegation in washington who would like to see it (the resolution) passed".
# \item Barber, who is in his 13th year as a legislator, said there "are some members of our congressional delegation in washington who would like to see it (the resolutions) passed".
# \end{enumerate}
#
# \begin{enumerate}
# \item But he added that none of georgia's congressmen specifically asked him to offer the resolution.
# \item But helium added that none of georgia's congressmen specifically asked him to offer the resolution.
# \item But he added that none of georgia's congressmen specifically asked him to offers the resolution.
# \end{enumerate}
#
# \begin{enumerate}
# \item The resolution, which barber tossed into the house hopper friday, will be formally read monday.
# \item The result, which barber tossed into the house hopper friday, will be formally read monday.
# \item The resolution, which barber tossed into the house hopper friday, will be formally read tuesday.
# \end{enumerate}
#
# \begin{enumerate}
# \item It says that "in the event congress does provide this increase in federal funds", the state board of education should be directed to "give priority" to teacher pay raises.
# \item It say that "in the event congress does provide this increase in federal funds", the state board of education should be directed to "give priority" to teacher pay raises.
# \item It says that "in the event congress does providing this increase in federal funds", the state board of education should be directed to "give priority" to teacher pay raises.
# \end{enumerate}
#
# \begin{enumerate}
# \item -- after a long, hot controversy, miller county has a new school superintendent, elected, as a policeman put it, in the "coolest election i ever saw in this county".
# \item -- after adenine long, hot controversy, miller county has a new school superintendent, elected, as a policeman put it, in the "coolest election i ever saw in this county".
# \item -- after a long, hot controversy, miller county has a new school superintendent, elected, as a policemen put it, in the "coolest election i ever saw in this county".
# \end{enumerate}
#
# \begin{enumerate}
# \item The new school superintendent is harry davis, a veteran agriculture teacher, who defeated felix bush, a school principal and chairman of the miller county democratic executive committee.
# \item The new schoolhouse superintendent is harry davis, a veteran agriculture teacher, who defeated felix bush, a school principal and chairman of the miller county democratic executive committee.
# \item The new school superintendent is harry davis, a veteran agricultural teacher, who defeated felix bush, a school principal and chairman of the miller county democratic executive committee.
# \end{enumerate}
#
# \begin{enumerate}
# \item Davis received 1,119 votes in saturday's election, and bush got 402.
# \item Davis received 1,119 voting in saturday's election, and bush got 402.
# \item Davis received 1,119 votes in saturday's elections, and bush got 402.
# \end{enumerate}
#
# \begin{enumerate}
# \item Ordinary carey williams, armed with a pistol, stood by at the polls to insure order.
# \item Ordinary carey williams, armed with adenine pistol, stood by at the polls to insure order.
# \item Ordinary carey williams, armed with a pistol, stood by at the polls to insuring order.
# \end{enumerate}
#
# \begin{enumerate}
# \item "this was the coolest, calmest election i ever saw", colquitt policeman tom williams said.
# \item "this wa the coolest, calmest election i ever saw", colquitt policeman tom williams said.
# \item "this was the coolest, calmest election i ever saw", colquitt policemen tom williams said.
# \end{enumerate}
#
# \begin{enumerate}
# \item "being at the polls was just like being at church.
# \item "existence at the polls was just like being at church.
# \item "being at the elections was just like being at church.
# \end{enumerate}
#
# \begin{enumerate}
# \item I didn't smell a drop of liquor, and we didn't have a bit of trouble".
# \item Iodine didn't smell a drop of liquor, and we didn't have a bit of trouble".
# \item I didn't smell a dropped of liquor, and we didn't have a bit of trouble".
# \end{enumerate}
#
# \begin{enumerate}
# \item The campaign leading to the election was not so quiet, however.
# \item The effort leading to the election was not so quiet, however.
# \item The campaigns leading to the election was not so quiet, however.
# \end{enumerate}
#
# \begin{enumerate}
# \item It was marked by controversy, anonymous midnight phone calls and veiled threats of violence.
# \item It wa marked by controversy, anonymous midnight phone calls and veiled threats of violence.
# \item It was marked by controversy, anonymous midnight phone calling and veiled threats of violence.
# \end{enumerate}
#
# \begin{enumerate}
# \item The former county school superintendent, george p. callan, shot himself to death march 18, four days after he resigned his post in a dispute with the county school board.
# \item The former county schoolhouse superintendent, george p. callan, shot himself to death march 18, four days after he resigned his post in a dispute with the county school board.
# \item The former county school superintendent, george p. callan, shot himself to death march 18, four days after he resigned his post in a disputes with the county school board.
# \end{enumerate}
#
# \begin{enumerate}
# \item During the election campaign, both candidates, davis and bush, reportedly received anonymous telephone calls.
# \item During the election effort, both candidates, davis and bush, reportedly received anonymous telephone calls.
# \item During the election campaign, both candidates, davis and bush, reportedly received anonymous phone calls.
# \end{enumerate}
#
# \begin{enumerate}
# \item Ordinary williams said he, too, was subjected to anonymous calls soon after he scheduled the election.
# \item Ordinary williams said helium, too, was subjected to anonymous calls soon after he scheduled the election.
# \item Ordinary williams said he, too, was subjected to anonymous calls soon after he scheduled the elections.
# \end{enumerate}
#
# \begin{enumerate}
# \item Many local citizens feared that there would be irregularities at the polls, and williams got himself a permit to carry a gun and promised an orderly election.
# \item Many local citizen feared that there would be irregularities at the polls, and williams got himself a permit to carry a gun and promised an orderly election.
# \item Many local citizens feared that there would be irregularities at the polls, and williams got himself a permit to carrying a gun and promised an orderly election.
# \end{enumerate}
#
# \begin{enumerate}
# \item Sheriff felix tabb said the ordinary apparently made good his promise.
# \item Sheriff felix tabb said the ordinary apparently made goodness his promise.
# \item Sheriff felix tabb said the ordinary apparently made great his promise.
# \end{enumerate}
#
# \begin{enumerate}
# \item "everything went real smooth", the sheriff said.
# \item "everything went real fast", the sheriff said.
# \item "everything came real smooth", the sheriff said.
# \end{enumerate}
#
# \begin{enumerate}
# \item "there wasn't a bit of trouble".
# \item "there wasn't adenine bit of trouble".
# \item "there wasn't a abit of trouble".
# \end{enumerate}
#
# \begin{enumerate}
# \item -- committee approval of gov. price daniel's "abandoned property" act seemed certain thursday despite the adamant protests of texas bankers.
# \item -- commission approval of gov. price daniel's "abandoned property" act seemed certain thursday despite the adamant protests of texas bankers.
# \item -- committee approval of gov. prices daniel's "abandoned property" act seemed certain thursday despite the adamant protests of texas bankers.
# \end{enumerate}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 for i in range(0, 100):
# ----> 2     original = trimmed_sents[i]
#       4     traditional = watermarked_sents[i]
#       5     deepTextMark = marker.watermark_single_sentence(original)
#
# IndexError: list index out of range
